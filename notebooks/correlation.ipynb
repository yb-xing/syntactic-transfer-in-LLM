# %% [markdown]
# ## Syntactic Transfer in LLMs — Correlation Analysis
#
# Run the cell below to launch the interactive UI.
#
# **Workflow:**
# 1. Enter surprisal CSV paths (one per line) and the RT data path, then click **Load Data**
# 2. Check the model pairs and regions you want to analyse
# 3. Choose whether to save results to disk or display them inline
# 4. Click **Run Analysis**

# %%
import importlib, sys, os
sys.path.insert(0, os.path.abspath("."))

from IPython.display import display, update_display
import ui as ui_mod

importlib.reload(ui_mod)
ui = ui_mod.CorrelationUI()

if "_ui_display_id" not in globals():
    _ui_display_id = "correlation_ui_singleton"
    display(ui._root, display_id=_ui_display_id)
else:
    update_display(ui._root, display_id=_ui_display_id)
